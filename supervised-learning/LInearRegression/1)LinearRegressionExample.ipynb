# %% [markdown]
# # Example for linear Regression Model

# %% [markdown]
# ### Loading all the libraries

# %%
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the data

# %%
data=np.loadtxt("data.csv",delimiter=",")

# %%
data.shape
# Out:
# (100, 2)

# %%
x=data[:,0].reshape(-1,1)
y=data[:,1].reshape(-1,1)

# %% [markdown]
# ### Spliting the dataset into train and test

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y)

# %% [markdown]
# ### Training or fitting the data to the algorithm

# %%
alg1=LinearRegression()
alg1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
m=alg1.coef_[0]
c=alg1.intercept_
m,c
# Out:
# (array([1.29971626]), array([8.90999729]))

# %% [markdown]
# ### Plotting the prediction and the data on a graph

# %%
plt.scatter(X_train,Y_train)
x_line=np.arange(30,70,0.1)
y_line=m*x_line+c
plt.plot(x_line,y_line,"r")
plt.show()

# %%
plt.scatter(X_test,Y_test)
plt.plot(x_line,y_line,"r")
plt.show()

# %% [markdown]
# ### Scoring the algorithmn

# %%
alg1.score(X_train,Y_train)
# Out:
# 0.5716398430249064

# %%
alg1.score(X_test,Y_test)
# Out:
# 0.6549032906293976
